# %% [markdown]
# ### Tutorial - Biblioteca Matplotlib (Python)
#
# > https://youtu.be/OZOOLe2imFo?si=8oSE4YljhkJxByCQ

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    # %pip install matplotlib
    import matplotlib.pyplot as plt

# %%
try:
    import numpy as np
except ImportError:
    # %pip install numpy
    import numpy as np

# %%
x_data = np.random.random(1000) * 100
y_data = np.random.random(1000) * 100

plt.scatter(x_data, y_data, c="darkblue", marker="*", alpha=0.3)
plt.show()

# %%
print(x_data)
print(y_data)
# Out:
# [80.02158033 30.93779054  8.05751191 44.31530049 92.75606583 29.25692146
#  78.6853017   7.59820206 48.42738772 17.42859992  8.77587959 89.15310497
#  97.86350336  8.79550678 71.07590115 93.04785635 26.24844414 75.42457149
#  35.72866161 29.33913746 52.33721884 72.89196452  9.37363936 19.09798624
#  64.6411394  21.15741316 29.78761454 68.62606406  7.81179089 25.78005182
#  95.55907816  4.6273736   0.42901856 64.28035881 76.95313668 26.2669054
#  64.39945575 60.7246764  84.79703391 48.39772274 64.19989733 85.61795677
#  48.23496258 40.11620752 99.50645641 53.36589515 34.51140118 88.03939364
#   1.34763541 66.87487303 89.17120169 83.66323803 93.58966901 22.50395036
#   2.99008193 94.41342389 24.39269524 95.54207483 40.02231834 70.47141768
#  84.01102924 31.96247314 96.24532319 85.12486318 81.19516613 72.1668452
#  87.63087111 56.09560762 62.76979258 19.63617616 88.09096291 15.27724214
#  75.94239203 54.85679421 59.84858804  1.40318697 21.7803117  44.31422148
# ...

# %%
years = [2006 + x for x in range(16)]
weights = [80, 83, 84, 85, 86, 82, 81, 79, 83, 80,
           82, 82, 83, 81, 80, 79]

plt.plot (years, weights, lw=3, linestyle="--")
plt.show()

# %%
# dados categóricos
x = ["C++", "C#", "Python", "Java", "Go"]
y = [20, 50, 140, 1, 45]

plt.bar(x, y)
plt.show()
